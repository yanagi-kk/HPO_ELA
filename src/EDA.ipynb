# %%
import pandas as pd
import numpy as np

# %%
config = {
    "name": "all", # dataset, algo, param, metrics
}

csv_path = f"../exp_results/for_idea/{config['name']}.csv"

# %%
df = pd.read_csv(csv_path)
df
# Out:
#     id           dataset algorithm  params_num  metrics  ic.h_max  ic.eps_s  \
# 0    1              wilt       XGB           4  logloss  0.406450 -2.617618
# 1    2               ada       XGB           4  logloss  0.409019 -2.377377
# 2    3  analcatdata-dmft       XGB           4  logloss  0.097207 -3.578579
# 3    4    bank-marketing       XGB           4  logloss  0.823197 -2.017017
# 4    5    cylinder-bands       XGB           4  logloss  0.117603 -2.917918
# 5    6              wilt      lgbm           4  logloss  0.117603 -2.677678
# 6    7               ada      lgbm           4  logloss  0.417229 -2.517518
# 7    8  analcatdata-dmft      lgbm           4  logloss  0.023171      -inf
# 8    9    bank-marketing      lgbm           4  logloss  0.807481 -2.317317
# 9   10    cylinder-bands      lgbm           4  logloss  0.093887 -3.318318
# 10  11              wilt       XGB           3  logloss  0.790337 -0.815816
# ...

# %%
base_cols = ["dataset", "algorithm", "params_num", "metrics"]
select_cols = [col for col in df.columns if col.startswith("ela_meta") or col.startswith("ela_distr")]

# %% [markdown]
# # データセットの違い

# %% [markdown]
# ## XGB

# %%
df_xgb_data = df.copy()[base_cols+select_cols].head(5)
df_xgb_data
# Out:
#             dataset algorithm  params_num  metrics  \
# 0              wilt       XGB           4  logloss
# 1               ada       XGB           4  logloss
# 2  analcatdata-dmft       XGB           4  logloss
# 3    bank-marketing       XGB           4  logloss
# 4    cylinder-bands       XGB           4  logloss
#
#    ela_meta.lin_simple.adj_r2  ela_meta.lin_simple.intercept  \
# 0                    0.440349                      -0.187839
# 1                    0.578926                      -0.435570
# 2                    0.035502                      -1.790752
# 3                    0.218744                      -0.374113
# 4                    0.093964                      -0.686212
#
#    ela_meta.lin_simple.coef.min  ela_meta.lin_simple.coef.max  \
# 0                  5.083354e-07                      0.001026
# 1                  9.395436e-06                      0.002268
# 2                  1.650867e-07                      0.000053
# ...

# %% [markdown]
# ## lgbm

# %%
df_lgbm_data = df.copy()[base_cols+select_cols].query("algorithm == 'lgbm' and params_num == 4")
df_lgbm_data
# Out:
#             dataset algorithm  params_num  metrics  \
# 5              wilt      lgbm           4  logloss
# 6               ada      lgbm           4  logloss
# 7  analcatdata-dmft      lgbm           4  logloss
# 8    bank-marketing      lgbm           4  logloss
# 9    cylinder-bands      lgbm           4  logloss
#
#    ela_meta.lin_simple.adj_r2  ela_meta.lin_simple.intercept  \
# 5                    0.090002                      -0.199017
# 6                    0.565707                      -0.440255
# 7                    0.014580                      -1.788405
# 8                    0.052932                      -0.338774
# 9                    0.045296                      -0.682536
#
#    ela_meta.lin_simple.coef.min  ela_meta.lin_simple.coef.max  \
# 5                  2.731275e-06                      0.000826
# 6                  5.259303e-06                      0.004741
# 7                  1.667266e-07                      0.000049
# ...

# %% [markdown]
# # アルゴリズムの違い

# %% [markdown]
# ## wilt

# %%
df_wilt_algo = df.copy()[base_cols+select_cols].query("dataset == 'wilt' and params_num == 4")
df_wilt_algo
# Out:
#   dataset algorithm  params_num  metrics  ela_meta.lin_simple.adj_r2  \
# 0    wilt       XGB           4  logloss                    0.440349
# 5    wilt      lgbm           4  logloss                    0.090002
#
#    ela_meta.lin_simple.intercept  ela_meta.lin_simple.coef.min  \
# 0                      -0.187839                  5.083354e-07
# 5                      -0.199017                  2.731275e-06
#
#    ela_meta.lin_simple.coef.max  ela_meta.lin_simple.coef.max_by_min  \
# 0                      0.001026                          2019.142733
# 5                      0.000826                           302.395134
#
#    ela_meta.lin_w_interact.adj_r2  ela_meta.quad_simple.adj_r2  \
# 0                        0.442960                     0.791839
# 5                        0.105715                     0.219565
#
#    ela_meta.quad_simple.cond  ela_meta.quad_w_interact.adj_r2  \
# 0               3.140909e+06                         0.942875
# ...

# %% [markdown]
# ## ada

# %%
df_ada_algo = df.copy()[base_cols+select_cols].query("dataset == 'ada' and params_num == 4")
df_ada_algo
# Out:
#   dataset algorithm  params_num  metrics  ela_meta.lin_simple.adj_r2  \
# 1     ada       XGB           4  logloss                    0.578926
# 6     ada      lgbm           4  logloss                    0.565707
#
#    ela_meta.lin_simple.intercept  ela_meta.lin_simple.coef.min  \
# 1                      -0.435570                      0.000009
# 6                      -0.440255                      0.000005
#
#    ela_meta.lin_simple.coef.max  ela_meta.lin_simple.coef.max_by_min  \
# 1                      0.002268                           241.444410
# 6                      0.004741                           901.485089
#
#    ela_meta.lin_w_interact.adj_r2  ela_meta.quad_simple.adj_r2  \
# 1                        0.580521                     0.910629
# 6                        0.572536                     0.894914
#
#    ela_meta.quad_simple.cond  ela_meta.quad_w_interact.adj_r2  \
# 1               2.248428e+07                         0.969792
# ...

# %% [markdown]
# # パラメータの数の違い

# %% [markdown]
# ## XGB

# %%
df_xgb_param = df.copy()[base_cols+select_cols].query("dataset == 'wilt' and algorithm == 'XGB'")
df_xgb_param
# Out:
#    dataset algorithm  params_num  metrics  ela_meta.lin_simple.adj_r2  \
# 0     wilt       XGB           4  logloss                    0.440349
# 10    wilt       XGB           3  logloss                    0.627494
# 11    wilt       XGB           2  logloss                    0.149670
# 12    wilt       XGB           1  logloss                    0.168603
#
#     ela_meta.lin_simple.intercept  ela_meta.lin_simple.coef.min  \
# 0                       -0.187839                  5.083354e-07
# 10                      -0.094344                  4.514351e-05
# 11                      -0.053772                  1.254377e-04
# 12                      -0.053003                  1.636745e-02
#
#     ela_meta.lin_simple.coef.max  ela_meta.lin_simple.coef.max_by_min  \
# 0                       0.001026                          2019.142733
# 10                      0.091512                          2027.134059
# 11                      0.015751                           125.565682
# ...

# %% [markdown]
# ## lgbm

# %%
df_lgbm_param = df.copy()[base_cols+select_cols].query("dataset == 'wilt' and algorithm == 'lgbm'")
df_lgbm_param
# Out:
#    dataset algorithm  params_num  metrics  ela_meta.lin_simple.adj_r2  \
# 5     wilt      lgbm           4  logloss                    0.090002
# 13    wilt      lgbm           3  logloss                    0.787050
# 14    wilt      lgbm           2  logloss                    0.596016
# 15    wilt      lgbm           1  logloss                    0.714708
#
#     ela_meta.lin_simple.intercept  ela_meta.lin_simple.coef.min  \
# 5                       -0.199017                      0.000003
# 13                      -0.068893                      0.000065
# 14                       0.270372                      0.133112
# 15                       0.961365                      4.702514
#
#     ela_meta.lin_simple.coef.max  ela_meta.lin_simple.coef.max_by_min  \
# 5                       0.000826                           302.395134
# 13                      0.036745                           564.209672
# 14                      3.328707                            25.006844
# ...
